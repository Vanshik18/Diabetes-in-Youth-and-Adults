# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\MY PC\\Downloads\\diabetes_young_adults_india.csv")

# %%
df.head()
# Out:
#    ID  Age  Gender     Region  Family_Income Family_History_Diabetes  \
# 0   1   21    Male      North        2209393                      No
# 1   2   18  Female    Central         387650                      No
# 2   3   25    Male      North         383333                      No
# 3   4   22    Male  Northeast        2443733                      No
# 4   5   19    Male    Central        1449463                      No
#
#   Parent_Diabetes_Type  Genetic_Risk_Score   BMI Physical_Activity_Level  ...  \
# 0                 None                   6  31.4               Sedentary  ...
# 1                 None                   5  24.4                  Active  ...
# 2                 None                   6  20.0                Moderate  ...
# 3                 None                   4  39.8                Moderate  ...
# 4                 None                   4  19.2                Moderate  ...
#
#   Smoking  Alcohol_Consumption Fasting_Blood_Sugar HbA1c  Cholesterol_Level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ID                       100000 non-null  int64
#  1   Age                      100000 non-null  int64
#  2   Gender                   100000 non-null  object
#  3   Region                   100000 non-null  object
#  4   Family_Income            100000 non-null  int64
#  5   Family_History_Diabetes  100000 non-null  object
#  6   Parent_Diabetes_Type     100000 non-null  object
#  7   Genetic_Risk_Score       100000 non-null  int64
#  8   BMI                      100000 non-null  float64
#  9   Physical_Activity_Level  100000 non-null  object
#  10  Dietary_Habits           100000 non-null  object
#  11  Fast_Food_Intake         100000 non-null  int64
#  12  Smoking                  100000 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Region                     0
# Family_Income              0
# Family_History_Diabetes    0
# Parent_Diabetes_Type       0
# Genetic_Risk_Score         0
# BMI                        0
# Physical_Activity_Level    0
# Dietary_Habits             0
# Fast_Food_Intake           0
# Smoking                    0
# Alcohol_Consumption        0
# Fasting_Blood_Sugar        0
# HbA1c                      0
# Cholesterol_Level          0
# Prediabetes                0
# Diabetes_Type              0
# Sleep_Hours                0
# Stress_Level               0
# Screen_Time                0
# dtype: int64

# %%
df.tail()
# Out:
#            ID  Age  Gender   Region  Family_Income Family_History_Diabetes  \
# 99995   99996   19  Female    South        2006887                      No
# 99996   99997   18  Female  Central        1102572                      No
# 99997   99998   23  Female  Central        1901854                      No
# 99998   99999   24    Male     West         564931                      No
# 99999  100000   18  Female    North        1972687                     Yes
#
#       Parent_Diabetes_Type  Genetic_Risk_Score   BMI Physical_Activity_Level  \
# 99995                 None                   2  39.6               Sedentary
# 99996               Type 1                   3  18.4                  Active
# 99997               Type 2                   5  35.5               Sedentary
# 99998                 None                   2  34.8                Moderate
# 99999               Type 1                   4  26.7                  Active
#
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Family_Income  Genetic_Risk_Score  \
# count  100000.000000  100000.000000   1.000000e+05       100000.000000
# mean    50000.500000      20.007890   1.299440e+06            5.505340
# std     28867.657797       3.154934   6.919403e+05            2.872218
# min         1.000000      15.000000   1.000040e+05            1.000000
# 25%     25000.750000      17.000000   7.022028e+05            3.000000
# 50%     50000.500000      20.000000   1.299990e+06            6.000000
# 75%     75000.250000      23.000000   1.898916e+06            8.000000
# max    100000.000000      25.000000   2.499974e+06           10.000000
#
#                  BMI  Fast_Food_Intake  Fasting_Blood_Sugar          HbA1c  \
# count  100000.000000     100000.000000        100000.000000  100000.000000
# mean       28.028089          4.988580           125.072216       7.006461
# std         6.924196          3.169762            31.788613       1.735327
# ...

# %%
df['Age']
# Out:
# 0        21
# 1        18
# 2        25
# 3        22
# 4        19
#          ..
# 99995    19
# 99996    18
# 99997    23
# 99998    24
# 99999    18
# Name: Age, Length: 100000, dtype: int64

# %%
sorted_df=df.sort_values(by='Age')

# %%
sorted_df.sample(15)
# Out:
#           ID  Age  Gender     Region  Family_Income Family_History_Diabetes  \
# 8673    8674   15    Male    Central         307669                      No
# 23637  23638   15  Female    Central        2389081                      No
# 14740  14741   15    Male       East        1995231                      No
# 18645  18646   20  Female       East        1294114                      No
# 63917  63918   20    Male       East         109522                      No
# 77203  77204   21    Male  Northeast        2089046                      No
# 77823  77824   15  Female       West        1878069                     Yes
# 97181  97182   23  Female      South        1741108                     Yes
# 92537  92538   19  Female      North        1791501                     Yes
# 44005  44006   21  Female       East        1284478                      No
# 10004  10005   15    Male      North        2444696                      No
# ...

# %%
bins = [15,20,26]  # Define the bin edges
labels = ['15-20', '20-26']

# %%
df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

print(df)
# Out:
#            ID  Age  Gender     Region  Family_Income Family_History_Diabetes  \
# 0           1   21    Male      North        2209393                      No
# 1           2   18  Female    Central         387650                      No
# 2           3   25    Male      North         383333                      No
# 3           4   22    Male  Northeast        2443733                      No
# 4           5   19    Male    Central        1449463                      No
# ...       ...  ...     ...        ...            ...                     ...
# 99995   99996   19  Female      South        2006887                      No
# 99996   99997   18  Female    Central        1102572                      No
# 99997   99998   23  Female    Central        1901854                      No
# 99998   99999   24    Male       West         564931                      No
# 99999  100000   18  Female      North        1972687                     Yes
#
# ...

# %%
grouped = df.groupby('Age_Group')

age_group_summary = grouped.size()

print(age_group_summary)
# Out:
# Age_Group
# 15-20    45258
# 20-26    54742
# dtype: int64

# %%
# Filter data for diabetic patients
diabetic_data = df[df['Diabetes_Type'] != 'None']

# %%
df['Has_Diabetes'] = df['Diabetes_Type'].apply(lambda x: 1 if x != 'None' else 0)
df.head()
# Out:
#    ID  Age  Gender     Region  Family_Income Family_History_Diabetes  \
# 0   1   21    Male      North        2209393                      No
# 1   2   18  Female    Central         387650                      No
# 2   3   25    Male      North         383333                      No
# 3   4   22    Male  Northeast        2443733                      No
# 4   5   19    Male    Central        1449463                      No
#
#   Parent_Diabetes_Type  Genetic_Risk_Score   BMI Physical_Activity_Level  ...  \
# 0                 None                   6  31.4               Sedentary  ...
# 1                 None                   5  24.4                  Active  ...
# 2                 None                   6  20.0                Moderate  ...
# 3                 None                   4  39.8                Moderate  ...
# 4                 None                   4  19.2                Moderate  ...
#
#   Fasting_Blood_Sugar  HbA1c Cholesterol_Level Prediabetes  Diabetes_Type  \
# ...

# %%
print(type1_counts)
print(type2_counts)
# Out:
# 15-20    2165
# 20-26    2762
# Name: Age_Group, dtype: int64
# 15-20     9247
# 20-26    11050
# Name: Age_Group, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Age', 'Gender', 'Region', 'Family_Income', 'Family_History_Diabetes', 'Parent_Diabetes_Type', 'Genetic_Risk_Score', 'BMI', 'Physical_Activity_Level', 'Dietary_Habits', 'Fast_Food_Intake', 'Smoking', 'Alcohol_Consumption', 'Fasting_Blood_Sugar', 'HbA1c', 'Cholesterol_Level', 'Prediabetes', 'Diabetes_Type', 'Sleep_Hours', 'Stress_Level', 'Screen_Time', 'Age_Group', 'Has_Diabetes']

# %%
print(df['Diabetes_Type'].unique())
print(df['Family_History_Diabetes'].unique())
# Out:
# ['None' 'Type 1' 'Type 2']
# ['No' 'Yes']

# %%
df['Diabetes_Type'] = df['Diabetes_Type'].astype('category')
df['Family_History_Diabetes'] = df['Family_History_Diabetes'].astype('category')

# %%
df['Has_Diabetes']=df['Has_Diabetes'].astype('bool')

# %%
# Create a new column for age groups
diabetic_data['Age_Group'] = pd.cut(diabetic_data['Age'], bins=bins, labels=labels, right=False)

# Count the number of diabetic patients in each age group
age_group_counts = diabetic_data['Age_Group'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(8, 6))
sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette='viridis')

# Add labels and title
plt.title('Number of Diabetic Patients by Age Group', fontsize=16)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Number of Patients', fontsize=14)
plt.xticks(fontsize=12)
# Out:
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_15828\2230606329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetic_data['Age_Group'] = pd.cut(diabetic_data['Age'], bins=bins, labels=labels, right=False)
# (array([0, 1]), [Text(0, 0, '15-20'), Text(1, 0, '20-26')])

# %%
# Separate data for Type 1 and Type 2 diabetes
type1_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 1']
type2_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 2']

# Count the number of patients in each age group for Type 1 and Type 2 diabetes
type1_counts = type1_data['Age_Group'].value_counts().sort_index()
type2_counts = type2_data['Age_Group'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=type1_counts.index, y=type1_counts.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_counts.index, y=type2_counts.values, color='orange', alpha=0.7, label='Type 2 Diabetes')

# Add labels and title
plt.title('Number of Diabetic Patients by Age Group and Diabetes Type', fontsize=14)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Number of Patients', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diabetes Type', fontsize=8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Diabetes_Type'], y=df['Genetic_Risk_Score'], palette='Set2')
plt.title('Distribution of Genetic Risk Score by Diabetes Type', fontsize=16)
plt.xlabel('Diabetes Type', fontsize=12)
plt.ylabel('Genetic Risk Score', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
type1_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 1']
type2_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 2']

# Count the number of patients in each age group for Type 1 and Type 2 diabetes
type1_count = type1_data['Gender'].value_counts().sort_index()
type2_count = type2_data['Gender'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=type1_count.index, y=type1_count.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_count.index, y=type2_count.values, color='orange', alpha=0.7, label='Type 2 Diabetes')

# Add labels and title
plt.title('Number of Diabetic Patients by Gender and Diabetes Type', fontsize=14)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Number of Patients', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diabetes Type', fontsize=8)
plt.tight_layout()
plt.show()

# %%
type1_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 1']
type2_data = diabetic_data[diabetic_data['Diabetes_Type'] == 'Type 2']

# Count the number of patients in each age group for Type 1 and Type 2 diabetes
type1_total = type1_data['Alcohol_Consumption'].value_counts().sort_index()
type2_total = type2_data['Alcohol_Consumption'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=type1_total.index, y=type1_total.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_total.index, y=type2_total.values, color='orange', alpha=0.7, label='Type 2 Diabetes')

# Add labels and title
plt.title('Number of Diabetic Patients by Alcohol_Consumption and Diabetes Type', fontsize=14)
plt.xlabel('Alcohal_Consumption', fontsize=10)
plt.ylabel('Number of Patients', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Diabetes Type', fontsize=8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18,12))

# Number of diabetic patients according to age group
plt.subplot(2,3,1)
sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette='viridis')

plt.title('Number of Diabetic Patients by Age Group', fontsize=10)
plt.xlabel('Age Group', fontsize=8)
plt.ylabel('Number of Patients', fontsize=8)
plt.xticks(fontsize=8)

#Number of Diabetic Patients by Age Group and Specific Diabetes Type
plt.subplot(2,3,2)
sns.barplot(x=type1_counts.index, y=type1_counts.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_counts.index, y=type2_counts.values, color='orange', alpha=0.7, label='Type 2 Diabetes')

# Add labels and title
plt.title('Number of Diabetic Patients by Age Group and Diabetes Type', fontsize=14)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Number of Patients', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diabetes Type', fontsize=8)

#Distribution of Genetic Risk Score by Diabetes Type
plt.subplot(2,3,3)
sns.boxplot(x=df['Diabetes_Type'], y=df['Genetic_Risk_Score'], palette='Set2')
plt.title('Distribution of Genetic Risk Score by Diabetes Type', fontsize=10)
plt.xlabel('Diabetes Type', fontsize=8)
plt.ylabel('Genetic Risk Score', fontsize=8)
plt.grid(axis='y', linestyle='--', alpha=0.7)


# Number of Diabetic Patients by Gender and Diabetes Type
plt.subplot(2,3,4)
sns.barplot(x=type1_count.index, y=type1_count.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_count.index, y=type2_count.values, color='orange', alpha=0.7, label='Type 2 Diabetes')
plt.title('Number of Diabetic Patients by Gender and Diabetes Type', fontsize=14)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Number of Patients', fontsize=10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Diabetes Type', fontsize=8)


# Number of Diabetic Patients by Alcohol_Consumption and Diabetes Type
plt.subplot(2,3,5)
sns.barplot(x=type1_total.index, y=type1_total.values, color='blue', alpha=0.7, label='Type 1 Diabetes')
sns.barplot(x=type2_total.index, y=type2_total.values, color='orange', alpha=0.7, label='Type 2 Diabetes')

plt.title('Number of Diabetic Patients by Alcohol_Consumption and Diabetes Type', fontsize=10)
plt.xlabel('Alcohal_Consumption', fontsize=8)
plt.ylabel('Number of Patients', fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(title='Diabetes Type', fontsize=8)

plt.suptitle("Diabetes in youth and Adult",fontsize=40)
plt.show()
